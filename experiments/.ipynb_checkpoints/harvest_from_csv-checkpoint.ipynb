# %%
import os
from src.csv_reader import parse_csv
from src.http_client import HttpClient
from src.ckan_client import CkanClient

# %% [markdown]
# # Load Data

# %%
rows  = parse_csv("../examples/harvest_sources.csv")

# %%
! pwd
# Out:
# /home/adminprod/jo/fedora-harvester/experiments

# %% [markdown]
# # Execute

# %%
base_url = os.getenv("CKAN_URL")
header = {"Authorization" : os.getenv("CKAN_API_KEY")}

# %%
http = HttpClient("https://48.220.49.10")

# %%
# resp = http.get("/api/3/action/organization_list", headers=header)
# resp.json()

# %%
# create organization 
def create_organization(rows: list) :
    header["Content-Type"] = "application/json"
    for row in rows :
        payload = {
            "name": row['owner_org'],
            "title": row['title'],
            "description": row['description']
        }
        http.post(path="/api/3/action/organization_create", json=payload, headers=header)

# %%
payload = {
    "name": rows[0]['name'],
    "title": rows[0]['title'],
    "notes": rows[0]['notes'],
    "url": rows[0]['url'],
    "source_type": rows[0]['source_type'],
    "frequency": rows[0]['frequency'],
    "owner_org": rows[0]['owner_org'],
    "type": "harvest"
}

# %%
ckan_client = CkanClient(base_url,os.getenv("CKAN_API_KEY"))

# %%
ckan_client.harvest_source_show("ispra").json()
# Out:
# /home/adminprod/.cache/uv/archive-v0/etBUkgxcBZZNctCe/lib/python3.12/site-packages/urllib3/connectionpool.py:1110: InsecureRequestWarning: Unverified HTTPS request is being made to host '48.220.49.10'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# {'help': 'https://48.220.49.10:443/api/3/action/help_show?name=harvest_source_show',
#  'success': True,
#  'result': {'creator_user_id': '9a2c2ad0-81e2-442e-9bf1-9c565fdf5471',
#   'frequency': 'DAILY',
#   'id': '0f77d0c3-b5fa-40ab-9d45-6aff10b0b45e',
#   'metadata_created': '2026-05-13T08:20:54.297741',
#   'metadata_modified': '2026-05-13T08:20:54.297749',
#   'name': 'ispra',
#   'notes': '',
#   'organization': {'id': '02c4afcd-d0ec-40f7-b822-5a4e1f56fa65',
#    'name': 'rep-isprambiente-it',
#    'title': 'ISPRA',
#    'type': 'organization',
#    'description': '',
#    'image_url': '',
#    'created': '2026-05-12T20:49:27.129452',
#    'is_organization': True,
#    'approval_status': 'approved',
#    'state': 'active'},
#   'owner_org': '02c4afcd-d0ec-40f7-b822-5a4e1f56fa65',
#   'private': False,
#   'source_type': 'dcat_rdf',
#   'state': 'active',
#   'title': 'ISPRA',
#   'type': 'harvest',
#   'url': 'https://rep.isprambiente.it/file/catalog/ispra_catalog.ttl',
#   'resources': [],
#   'tags': [],
#   'groups': [],
#   'relationships_as_subject': [],
#   'relationships_as_object': [],
#   'status': {'job_count': 0, 'last_job': None, 'total_datasets': 0},
#   'active': True}}

# %%
ckan_client.list_organizations()
# Out:
# /home/adminprod/.cache/uv/archive-v0/etBUkgxcBZZNctCe/lib/python3.12/site-packages/urllib3/connectionpool.py:1110: InsecureRequestWarning: Unverified HTTPS request is being made to host '48.220.49.10'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# {'help': 'https://48.220.49.10:443/api/3/action/help_show?name=organization_list',
#  'success': True,
#  'result': ['dati-gov-it',
#   'araba-irekia-open-data-euskadi',
#   'arpea-it',
#   'ayuntamiento-san-sebastian',
#   'ccca',
#   'data-gv-at',
#   'datavejviser-dk',
#   'dgt',
#   'donostia-eus-datosabiertos',
#   'gdi',
#   'geo-araba',
#   'geoeuskadi',
#   'data-hub-geosphere-at',
#   'geosphere_austria',
#   'gipuzkoa-irekia-euskadi',
#   'ign-es',
#   'infrabel',
#   'geoportal-inspire-gv-at',
#   'rep-isprambiente-it',
#   'mobilitydata-gv-at',
#   'opendata-dk',
#   'data-gov-cy',
#   'kozadatportal-hu',
#   'open-data-austria',
#   'opendata-bizkaia',
#   'open-data-emilia-romagna',
#   'open-data-euskadi',
#   'opendataportal-at',
#   'opendata-comune-re-it',
#   'traffic4cyprus-org-cy',
#   'voi']}

# %%
ckan_client.create_organization(payload)
# Out:
# /home/adminprod/.cache/uv/archive-v0/etBUkgxcBZZNctCe/lib/python3.12/site-packages/urllib3/connectionpool.py:1110: InsecureRequestWarning: Unverified HTTPS request is being made to host '48.220.49.10'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# {}

# %%
# ckan_client.harvest_job_create("0f77d0c3-b5fa-40ab-9d45-6aff10b0b45e")
